# %%
#Reading in the census dataset
import pandas as pd
import numpy as np
census = pd.read_csv("census.csv")
census.head(10)
# Out:
#    census_year state_fips_code  total_family_income  age     sex  \
# 0         2000         Florida              14550.0   44    Male
# 1         2000         Florida              22800.0   20  Female
# 2         2000         Florida                  0.0   20    Male
# 3         2000         Florida              23000.0    6  Female
# 4         2000         Florida              48000.0   55    Male
# 5         2000         Florida              74000.0   43  Female
# 6         2000         Florida              23000.0   60  Female
# 7         2000         Florida              74000.0   47  Female
# 8         2000         Florida              60000.0   54  Female
# 9         2000         Florida              14600.0   58  Female
#
#       race_general          marital_status  total_personal_income
# 0  Two major races  Married/spouse present                    0.0
# 1            White    Never married/single                13000.0
# 2            Black    Never married/single                20000.0
# 3            White    Never married/single                    NaN
# 4            White  Married/spouse present                36000.0
# 5            White  Married/spouse present                27000.0
# 6            White  Married/spouse present                11800.0
# 7            White  Married/spouse present                48000.0
# 8            Black  Married/spouse present                40000.0
# 9            White                 Widowed                14600.0

# %%
census.head(10)
# Out:
#   state_fips_code  total_family_income     race_general  \
# 0         Florida              14550.0  Two major races
# 1         Florida              22800.0            White
# 2         Florida                  0.0            Black
# 3         Florida              23000.0            White
# 4         Florida              48000.0            White
# 5         Florida              74000.0            White
# 6         Florida              23000.0            White
# 7         Florida              74000.0            White
# 8         Florida              60000.0            Black
# 9         Florida              14600.0            White
#
#            marital_status  total_personal_income
# 0  Married/spouse present                    0.0
# 1    Never married/single                13000.0
# 2    Never married/single                20000.0
# 3    Never married/single                    NaN
# 4  Married/spouse present                36000.0
# 5  Married/spouse present                27000.0
# 6  Married/spouse present                11800.0
# 7  Married/spouse present                48000.0
# 8  Married/spouse present                40000.0
# 9                 Widowed                14600.0

# %%
#dropping the column state_fips_code column
census = census.drop(["state_fips_code"], axis = 1)

# %%
census.tail(5)
# Out:
#      total_family_income race_general          marital_status  \
# 495               8500.0        White                Divorced
# 496              55400.0        White    Never married/single
# 497              15000.0        Black                 Widowed
# 498                  NaN        Black   Married/spouse absent
# 499              39370.0        White  Married/spouse present
#
#      total_personal_income
# 495                 8500.0
# 496                    NaN
# 497                15000.0
# 498                48600.0
# 499                19800.0

# %%
#Identifying the columns in the census dataset
print(census.columns)
# Out:
# Index(['total_family_income', 'race_general', 'marital_status',
#        'total_personal_income'],
#       dtype='object')

# %%
#selecting out integer index labels from 12-34 
census.iloc[12:34]
# Out:
#     total_family_income race_general          marital_status  \
# 12              32000.0        White                Divorced
# 13             113000.0        White    Never married/single
# 14              76900.0        White    Never married/single
# 15             100100.0        White  Married/spouse present
# 16              48000.0        White  Married/spouse present
# 17              48000.0        White    Never married/single
# 18              57200.0        White  Married/spouse present
# 19              43950.0        White  Married/spouse present
# 20              49000.0        White  Married/spouse present
# 21              31600.0        White                 Widowed
# 22              50090.0        White    Never married/single
# 23              64800.0        White    Never married/single
# 24              90000.0        White    Never married/single
# 25              38320.0        White  Married/spouse present
# 26             103700.0        White    Never married/single
# 27                  0.0        Black                 Widowed
# 28              70700.0        White    Never married/single
# 29              64800.0        White                Divorced
# 30              60000.0        White  Married/spouse present
# 31             118100.0        White    Never married/single
# 32              21000.0        White  Married/spouse present
# 33              40000.0        White  Married/spouse present
#
#     total_personal_income
# 12                32000.0
# 13                    NaN
# 14                 6000.0
# 15                16100.0
# 16                12000.0
# 17                    NaN
# 18                20000.0
# 19                 4800.0
# 20                28000.0
# 21                31600.0
# 22                    NaN
# 23                49300.0
# 24                    NaN
# 25                34320.0
# 26                    NaN
# 27                 8400.0
# 28                 3700.0
# 29                 4800.0
# 30                53000.0
# 31                 7500.0
# 32                 6000.0
# 33                    0.0

# %%
#selecting the first 10 rows of the column race_general
census["race_general"].head(10)
# Out:
# 0    Two major races
# 1              White
# 2              Black
# 3              White
# 4              White
# 5              White
# 6              White
# 7              White
# 8              Black
# 9              White
# Name: race_general, dtype: object

# %%
#selecting out rows with total_family_income greater than 50000
census[census["total_family_income"] > 50000].head(10)
# Out:
#     total_family_income race_general          marital_status  \
# 5               74000.0        White  Married/spouse present
# 7               74000.0        White  Married/spouse present
# 8               60000.0        Black  Married/spouse present
# 13             113000.0        White    Never married/single
# 14              76900.0        White    Never married/single
# 15             100100.0        White  Married/spouse present
# 18              57200.0        White  Married/spouse present
# 22              50090.0        White    Never married/single
# 23              64800.0        White    Never married/single
# 24              90000.0        White    Never married/single
#
#     total_personal_income
# 5                 27000.0
# 7                 48000.0
# 8                 40000.0
# 13                    NaN
# 14                 6000.0
# 15                16100.0
# 18                20000.0
# 22                    NaN
# 23                49300.0
# 24                    NaN

# %%
#Displaying the dimensions of the census dataset
print(census.shape)
# Out:
# (500, 4)

# %%
census = pd.DataFrame(census)
census.head(10)
# Out:
#    total_family_income     race_general          marital_status  \
# 0              14550.0  Two major races  Married/spouse present
# 1              22800.0            White    Never married/single
# 2                  0.0            Black    Never married/single
# 3              23000.0            White    Never married/single
# 4              48000.0            White  Married/spouse present
# 5              74000.0            White  Married/spouse present
# 6              23000.0            White  Married/spouse present
# 7              74000.0            White  Married/spouse present
# 8              60000.0            Black  Married/spouse present
# 9              14600.0            White                 Widowed
#
#    total_personal_income
# 0                    0.0
# 1                13000.0
# 2                20000.0
# 3                    NaN
# 4                36000.0
# 5                27000.0
# 6                11800.0
# 7                48000.0
# 8                40000.0
# 9                14600.0

# %%
#dropping all na values in census dataset
census.dropna()
# Out:
#      total_family_income     race_general          marital_status  \
# 0                14550.0  Two major races  Married/spouse present
# 1                22800.0            White    Never married/single
# 2                    0.0            Black    Never married/single
# 4                48000.0            White  Married/spouse present
# 5                74000.0            White  Married/spouse present
# ..                   ...              ...                     ...
# 492             119800.0            White    Never married/single
# 493              18000.0            White  Married/spouse present
# 495               8500.0            White                Divorced
# 497              15000.0            Black                 Widowed
# 499              39370.0            White  Married/spouse present
#
#      total_personal_income
# 0                      0.0
# 1                  13000.0
# 2                  20000.0
# 4                  36000.0
# 5                  27000.0
# ..                     ...
# 492                22000.0
# 493                18000.0
# 495                 8500.0
# 497                15000.0
# 499                19800.0
#
# [377 rows x 4 columns]

# %%
#pivoting a dataset
x = {'Year': [2019, 2019, 2020, 2020], 'Quarter': ['Q1', 'Q2', 'Q1', 'Q2'], 'Sales': [100, 200, 300, 400]}
y = pd.DataFrame(x)
y
y_new = y.pivot(index='Year', columns='Quarter', values='Sales')
y_new
# Out:
# Quarter   Q1   Q2
# Year
# 2019     100  200
# 2020     300  400

# %%
#Dropping the column census_year in the census dataset
census.head(10)
 census_new = census.drop(['census_year'], axis = 1)
#census.head(10)
#census = np.loadtxt('census.csv', delimiter=',')
# Out:
#     state_fips_code  total_family_income  age     sex     race_general  \
# 0           Florida              14550.0   44    Male  Two major races
# 1           Florida              22800.0   20  Female            White
# 2           Florida                  0.0   20    Male            Black
# 3           Florida              23000.0    6  Female            White
# 4           Florida              48000.0   55    Male            White
# ..              ...                  ...  ...     ...              ...
# 495        Virginia               8500.0   68  Female            White
# 496        Virginia              55400.0   12    Male            White
# 497        Virginia              15000.0   60    Male            Black
# 498        Virginia                  NaN   60    Male            Black
# 499        Virginia              39370.0   47    Male            White
#
#              marital_status  total_personal_income
# 0    Married/spouse present                    0.0
# 1      Never married/single                13000.0
# 2      Never married/single                20000.0
# 3      Never married/single                    NaN
# 4    Married/spouse present                36000.0
# ..                      ...                    ...
# 495                Divorced                 8500.0
# 496    Never married/single                    NaN
# 497                 Widowed                15000.0
# 498   Married/spouse absent                48600.0
# 499  Married/spouse present                19800.0
#
# [500 rows x 7 columns]
